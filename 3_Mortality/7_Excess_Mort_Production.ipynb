#                  VNM           YEM           ZMB           ZWE       ROW
# 0       9.392862e-16  1.124081e-07  7.186262e-07  2.573940e-07  0.000273
# 1       2.755908e-16  8.858789e-08  4.496146e-07  1.514931e-07  0.000325
# 2       6.555003e-17  4.562609e-08  1.996176e-07  6.421775e-08  0.000502
# 3       2.836252e-17  3.409333e-08  1.091611e-07  3.346118e-08  0.000490
# 4       5.501651e-17  3.374540e-08  6.793321e-08  2.099579e-08  0.001170
# ...              ...           ...           ...           ...       ...
# 273734  1.329057e-05  1.998196e-05  1.474786e-04  1.108508e-04  1.250272
# 273735  5.570503e-06  8.036247e-06  6.950759e-05  5.010601e-05  3.592422
# 273736  4.685011e-06  6.759963e-06  5.820945e-05  4.202173e-05  4.549325
# 273737  3.619399e-06  5.244419e-06  4.716335e-05  3.354287e-05  5.430701
# 273738  3.783375e-06  5.482256e-06  4.877434e-05  3.481212e-05  5.778483
#
# [273739 rows x 188 columns]

# %%
Sub_Country1 = Country[0:20]
# Sub_Country2 = Country[20:40]
# Sub_Country3 = Country[40:60]
# Sub_Country4 = Country[60:80]
# Sub_Country5 = Country[80:100]
# Sub_Country6 = Country[100:120]
# Sub_Country7 = Country[120:140]
# Sub_Country8 = Country[140:160]
# Sub_Country9 = Country[160:189]

# %%
# fraction = pd.read_csv('comparison/baseline_fraction_Hbar2.csv')
fraction = pd.read_csv('C:/Users/15311/Desktop/baseline_fraction_Hbar2.csv')

# %%
concentration_matrix['area_fraction'] = fraction['area_fraction']
concentration_matrix['base_mort'] = fraction['base_mort']
concentration_matrix['mort_per_con'] = fraction['mort_per_con']

# %%
total_mortality = {}

from tqdm import tqdm
for consume_country in tqdm(Sub_Country1):
    mortality0 = {}
    for country in Country:
        mortality0[country] = 0
        popdeath = 0
        for index in range(len(concentration_matrix)):
            if country not in json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"')).keys():
                continue
            popdeath += concentration_matrix.iloc[index][consume_country] * json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"'))[country]
        mortality0[country] += popdeath
    total_mortality[consume_country] = mortality0

# %% [markdown]
# ## Trail: time for one country to run the whole simulation

# %%
total_mortality = {}

from tqdm import tqdm
consume_country = 'CHN'
mortality0 = {}
for country in tqdm(Country):
    mortality0[country] = 0
    popdeath = 0
    for index in range(len(concentration_matrix)):
        if country not in json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"')).keys():
            continue
        popdeath += concentration_matrix.iloc[index][consume_country] * json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"'))[country]
    mortality0[country] += popdeath
total_mortality[consume_country] = mortality0
# Out:
#   6%|████▌                                                                          | 11/188 [14:08<3:47:33, 77.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-90dea47e6842> in <module>()
#       8     popdeath = 0
#       9     for index in range(len(concentration_matrix)):
# ---> 10         if country not in json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"')).keys():
#      11             continue
#      12         popdeath += concentration_matrix.iloc[index][consume_country] * json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"'))[country]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2138             self._validate_integer(key, axis)
#    2139
# -> 2140             return self._get_loc(key, axis=axis)
#    2141
#    2142     # raise_missing is included for compat with the parent class signature
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_loc(self, key, axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
# --> 628         return self.obj._ixs(key, axis=axis)
#     629
#     630     def _slice(self, obj, axis: int, kind=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _ixs(self, i, axis)
#    2733         # irow
#    2734         if axis == 0:
# -> 2735             new_values = self._data.fast_xs(i)
#    2736
#    2737             # if we are a copy, mark as such
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in fast_xs(self, loc)
#     912             result = np.empty(n, dtype=object)
#     913         else:
# --> 914             result = np.empty(n, dtype=dtype)
#     915
#     916         for blk in self.blocks:
#
# KeyboardInterrupt:

# %%
file=open("comparison/Excess_mort_production1.json",'w')
json.dump(total_mortality,file)
file.close()
