# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import salem
import copy
import json

# %%
concentration_matrix = pd.read_csv('C:/Users/15311/Desktop/concentration_matrix2.csv',index_col=0)
# concentration_matrix2.csv is with country name header.
# concentration_matrix = pd.read_csv('comparison/concentration_matrix2.csv',index_col=0)
# concentration_matrix = concentration_matrix.drop(['ANT','USR'],axis=1)
Country = list(concentration_matrix.columns)

# %%
concentration_matrix
# Out:
#                  AFG           ALB       DZA           AND       AGO  \
# 0       5.359969e-08  3.537154e-08  0.000003  2.722943e-08  0.000002
# 1       5.834354e-08  3.816871e-08  0.000004  3.136729e-08  0.000002
# 2       8.065263e-08  5.209372e-08  0.000006  4.663887e-08  0.000003
# 3       7.728184e-08  4.984932e-08  0.000006  4.528505e-08  0.000003
# 4       1.799151e-07  1.156564e-07  0.000014  1.072149e-07  0.000006
# ...              ...           ...       ...           ...       ...
# 273734  6.167611e-04  2.770478e-04  0.017140  1.626795e-04  0.007623
# 273735  1.864484e-03  8.346772e-04  0.049146  4.807639e-04  0.021807
# 273736  2.478675e-03  1.098999e-03  0.062864  6.222474e-04  0.027783
# 273737  3.006812e-03  1.327771e-03  0.075307  7.479158e-04  0.033223
# 273738  3.034742e-03  1.350129e-03  0.079269  7.761812e-04  0.035082
#
#                  ATG       ARG           ARM           ABW       AUS  ...  \
# 0       3.806444e-09  0.000022  3.311551e-08  8.583286e-09  0.000003  ...
# 1       3.773725e-09  0.000017  3.663019e-08  8.687873e-09  0.000003  ...
# 2       4.400378e-09  0.000012  5.097777e-08  1.046453e-08  0.000005  ...
# 3       4.085611e-09  0.000009  4.893945e-08  9.762127e-09  0.000005  ...
# 4       9.029982e-09  0.000016  1.139250e-07  2.180575e-08  0.000012  ...
# ...              ...       ...           ...           ...       ...  ...
# 273734  4.023941e-05  0.019119  2.808095e-04  7.610923e-05  0.256499  ...
# 273735  1.232206e-04  0.054527  8.415082e-04  2.311686e-04  0.541844  ...
# 273736  1.645512e-04  0.069724  1.106632e-03  3.069772e-04  0.702797  ...
# 273737  1.997889e-04  0.083432  1.334968e-03  3.718337e-04  0.844055  ...
# 273738  2.003488e-04  0.087702  1.355604e-03  3.744253e-04  0.843835  ...
#
#              USA           URY           UZB           VUT       VEN  \
# 0       0.000030  6.637447e-07  7.996932e-07  3.975315e-09  0.000029
# 1       0.000033  4.468515e-07  9.383544e-07  3.807891e-09  0.000032
# 2       0.000045  2.748242e-07  1.425254e-06  4.319701e-09  0.000043
# 3       0.000044  1.920005e-07  1.388792e-06  3.972079e-09  0.000041
# 4       0.000102  3.138425e-07  3.303126e-06  8.733737e-09  0.000095
# ...          ...           ...           ...           ...       ...
# 273734  0.299570  7.605781e-04  4.341694e-03  3.069543e-04  0.110664
# 273735  0.897237  1.996215e-03  1.267580e-02  1.011910e-03  0.319331
# 273736  1.180493  2.608247e-03  1.627010e-02  1.382851e-03  0.407455
# 273737  1.420911  3.141515e-03  1.950420e-02  1.689412e-03  0.487757
# 273738  1.432297  3.201735e-03  2.042582e-02  1.670022e-03  0.514813
#
#                  VNM           YEM           ZMB           ZWE  ROW
# 0       4.720066e-07  4.040659e-07  5.417890e-07  2.779242e-07  0.0
# 1       5.413872e-07  4.331538e-07  3.842346e-07  1.829711e-07  0.0
# 2       8.016187e-07  5.742822e-07  2.864733e-07  1.216361e-07  0.0
# 3       7.775619e-07  5.498045e-07  2.263148e-07  9.102658e-08  0.0
# 4       1.839831e-06  1.263305e-06  4.242226e-07  1.617730e-07  0.0
# ...              ...           ...           ...           ...  ...
# 273734  1.195531e-02  1.999765e-03  9.744218e-04  5.156231e-04  0.0
# 273735  3.602883e-02  5.668469e-03  2.528534e-03  1.229702e-03  0.0
# 273736  4.830983e-02  7.344652e-03  3.290704e-03  1.592518e-03  0.0
# 273737  5.865929e-02  8.839924e-03  3.955133e-03  1.901830e-03  0.0
# 273738  5.852970e-02  9.181616e-03  4.047248e-03  1.924933e-03  0.0
#
# [273739 rows x 188 columns]

# %%
Sub_Country1 = Country[0:20]
# Sub_Country2 = Country[20:40]
# Sub_Country3 = Country[40:60]
# Sub_Country4 = Country[60:80]
# Sub_Country5 = Country[80:100]
# Sub_Country6 = Country[100:120]
# Sub_Country7 = Country[120:140]
# Sub_Country8 = Country[140:160]
# Sub_Country9 = Country[160:189]

# %%
# fraction = pd.read_csv('comparison/baseline_fraction_Hbar2.csv')
fraction = pd.read_csv('C:/Users/15311/Desktop/baseline_fraction_Hbar2.csv')

# %%
concentration_matrix['area_fraction'] = fraction['area_fraction']
concentration_matrix['base_mort'] = fraction['base_mort']
concentration_matrix['mort_per_con'] = fraction['mort_per_con']

# %%
total_mortality = {}

from tqdm import tqdm
for consume_country in tqdm(Sub_Country1):
    mortality0 = {}
    for country in Country:
        mortality0[country] = 0
        popdeath = 0
        for index in range(len(concentration_matrix)):
            if country not in json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"')).keys():
                continue
            popdeath += concentration_matrix.iloc[index][consume_country] * json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"'))[country]
        mortality0[country] += popdeath
    total_mortality[consume_country] = mortality0

# %% [markdown]
# ## Trail: time for one country to run the whole simulation

# %%
total_mortality = {}

from tqdm import tqdm
consume_country = 'CHN'
mortality0 = {}
for country in tqdm(Country):
    mortality0[country] = 0
    popdeath = 0
    for index in range(len(concentration_matrix)):
        if country not in json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"')).keys():
            continue
        popdeath += concentration_matrix.iloc[index][consume_country] * json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"'))[country]
    mortality0[country] += popdeath
total_mortality[consume_country] = mortality0
# Out:
#   6%|████▌                                                                          | 11/188 [14:08<3:47:33, 77.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-90dea47e6842> in <module>()
#       8     popdeath = 0
#       9     for index in range(len(concentration_matrix)):
# ---> 10         if country not in json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"')).keys():
#      11             continue
#      12         popdeath += concentration_matrix.iloc[index][consume_country] * json.loads(concentration_matrix.iloc[index]['mort_per_con'].replace('\'','\"'))[country]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2138             self._validate_integer(key, axis)
#    2139
# -> 2140             return self._get_loc(key, axis=axis)
#    2141
#    2142     # raise_missing is included for compat with the parent class signature
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_loc(self, key, axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
# --> 628         return self.obj._ixs(key, axis=axis)
#     629
#     630     def _slice(self, obj, axis: int, kind=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _ixs(self, i, axis)
#    2733         # irow
#    2734         if axis == 0:
# -> 2735             new_values = self._data.fast_xs(i)
#    2736
#    2737             # if we are a copy, mark as such
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in fast_xs(self, loc)
#     912             result = np.empty(n, dtype=object)
#     913         else:
# --> 914             result = np.empty(n, dtype=dtype)
#     915
#     916         for blk in self.blocks:
#
# KeyboardInterrupt:

# %%
file=open("comparison/Excess_mort_consumption1.json",'w')
json.dump(total_mortality,file)
file.close()
